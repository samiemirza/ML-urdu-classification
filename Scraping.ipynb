# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /opt/anaconda3/envs/ML_env/lib/python3.12/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/ML_env/lib/python3.12/site-packages (from BeautifulSoup4) (2.6)

# %%
import os
import json
import time
import random
import zipfile
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Class Explanation: `NewsScraper`
#
# ## Overview
# The `NewsScraper` class is designed for scraping news articles from three different Urdu news websites: Geo, Jang, and Express. The class has methods that cater to each site's unique structure and requirements. Below, we will go through the class and its methods, detailing what each function does, the input it takes, and the output it returns.
#
# ## Class Definition
#
# ```python
# class NewsScraper:
#     def __init__(self, id_=0):
#         self.id = id_
# ```
#
#
# ## Method 1: `get_express_articles`
#
# ### Description
# Scrapes news articles from the Express website across categories like saqafat (entertainment), business, sports, science-technology, and world. The method navigates through multiple pages for each category to gather a more extensive dataset.
#
# ### Input
# - **`max_pages`**: The number of pages to scrape for each category (default is 7).
#
# ### Process
# - Iterates over each category and page.
# - Requests each category page and finds article cards within `<ul class='tedit-shortnews listing-page'>`.
# - Extracts the article's headline, link, and content by navigating through `<div class='horiz-news3-caption'>` and `<span class='story-text'>`.
#
# ### Output
# - **Returns**: A tuple of:
#   - A Pandas DataFrame containing columns: `id`, `title`, and `link`).
#   - A dictionary `express_contents` where the key is the article ID and the value is the article content.
#
# ### Data Structure
# - Article cards are identified by `<li>` tags.
# - Content is structured within `<span class='story-text'>` and `<p>` tags.

# %%
class NewsScraper:
    def __init__(self,id_=0):
        self.id = id_


  # write functions to scrape from other websites


    def get_express_articles(self, max_pages=7):
        express_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://www.express.pk'
        categories = ['saqafat', 'business', 'sports', 'science', 'world']   # saqafat is entertainment category

        # Iterating over the specified number of pages
        for category in categories:
            for page in range(1, max_pages + 1):
                print(f"Scraping page {page} of category '{category}'...")
                url = f"{base_url}/{category}/archives?page={page}"
                response = requests.get(url)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, "html.parser")

                # Finding article cards
                cards = soup.find('ul', class_='tedit-shortnews listing-page').find_all('li')  # Adjust class as per actual site structure
                print(f"\t--> Found {len(cards)} articles on page {page} of '{category}'.")

                success_count = 0

                for card in cards:
                    try:
                        div = card.find('div',class_='horiz-news3-caption')

                        # Article Title
                        headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')

                        # Article link
                        link = div.find('a')['href']

                        # Requesting the content from each article's link
                        article_response = requests.get(link)
                        article_response.raise_for_status()
                        content_soup = BeautifulSoup(article_response.text, "html.parser")


                        # Content arranged in paras inside <span> tags
                        paras = content_soup.find('span',class_='story-text').find_all('p')

                        combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                        )

                        # Storing data
                        express_df['id'].append(self.id)
                        express_df['title'].append(headline)
                        express_df['link'].append(link)
                        express_df['gold_label'].append(category.replace('saqafat','entertainment').replace('science','science-technology'))
                        express_df['content'].append(combined_text)

                        # Increment ID and success count
                        self.id += 1
                        success_count += 1

                    except Exception as e:
                        print(f"\t--> Failed to scrape an article on page {page} of '{category}': {e}")

                print(f"\t--> Successfully scraped {success_count} articles from page {page} of '{category}'.")
            print('')

        return pd.DataFrame(express_df)
    
    def get_geo_urdu_articles(self): #only one page
        geo_urdu_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://urdu.geo.tv'
        categories = ['entertainment', 'business', 'sports', 'science-technology', 'world']


        # Iterating over the specified number of pages
        for category in categories:
            #for page in range(1, max_pages + 1):
            print(f"Scraping category '{category}'...")
            url = f"{base_url}/category/{category}"
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")

            # Finding article cards
            cards = soup.find_all('li', class_='border-box')  # Adjust class as per actual site structure
            print(f"\t--> Found {len(cards)} of '{category}'.")

            success_count = 0

            for card in cards:
                try:
                    #div = card.find('div',class_='border-box')
                    div = card

                    # Article Title
                    headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')
                    
                    # Article link
                    link = div.find('a', class_='open-section')['href']

                    # Requesting the content from each article's link
                    article_response = requests.get(link)
                    article_response.raise_for_status()
                    content_soup = BeautifulSoup(article_response.text, "html.parser")

                    # Content arranged in paras inside <span> tags
                    paras = content_soup.find('div',class_='content-area').find_all('p')

                    combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                    )

                    # Storing data
                    geo_urdu_df['id'].append(self.id)
                    geo_urdu_df['title'].append(headline)
                    geo_urdu_df['link'].append(link)
                    geo_urdu_df['gold_label'].append(category)
                    geo_urdu_df['content'].append(combined_text)

                    # Increment ID and success count
                    self.id += 1
                    success_count += 1

                except Exception as e:
                    print(f"\t--> Failed to scrape'{category}': {e}")

                print(f"\t--> Successfully scraped {success_count} articles from '{category}'.")
            print('')

        return pd.DataFrame(geo_urdu_df)

    def get_jang_articles(self): #only one page
        jang_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://jang.com.pk'
        categories = ['entertainment', 'business', 'sports', 'science-technology', 'world']


        # Iterating over the specified number of pages
        for category in categories:
            #for page in range(1, max_pages + 1):
            print(f"Scraping category '{category}'...")
            url = f"{base_url}/category/latest-news/{category}"
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")

            # Finding article cards
            cards = soup.find('ul', class_='scrollPaginationNew__').find_all('li')  # Adjust class as per actual site structure
            print(f"\t--> Found {len(cards)} of '{category}'.")

            success_count = 0

            for card in cards:
                try:
                    div = card.find('div',class_='main-heading')
                    #div = card

                    # Article Title
                    headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')
                    
                    # Article link
                    link = div.find('a')['href']

                    # Requesting the content from each article's link
                    article_response = requests.get(link)
                    article_response.raise_for_status()
                    content_soup = BeautifulSoup(article_response.text, "html.parser")

                    # Content arranged in paras inside <span> tags
                    paras = content_soup.find('div',class_='detail_view_content').find_all('p')

                    combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                    )

                    # Storing data
                    jang_df['id'].append(self.id)
                    jang_df['title'].append(headline)
                    jang_df['link'].append(link)
                    jang_df['gold_label'].append(category)
                    jang_df['content'].append(combined_text)

                    # Increment ID and success count
                    self.id += 1
                    success_count += 1

                except Exception as e:
                    print(f"\t--> Failed to scrape'{category}': {e}")
                
                print(f"\t--> Successfully scraped {success_count} articles from '{category}'.")
            
            print('')

        return pd.DataFrame(jang_df)

    def get_dunya_articles(self): #only one page
        dunya_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://urdu.dunyanews.tv'
        categories = ['Entertainment', 'Business', 'Sports', 'Technology', 'World']


        # Iterating over the specified number of pages
        for category in categories:
            #for page in range(1, max_pages + 1):
            print(f"Scraping category '{category}'...")
            url = f"{base_url}/index.php/ur/{category}"
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")

            # Finding article cards
            cards = soup.find('div', class_='newsBox categories').find_all('div')  # Adjust class as per actual site structure
            print(f"\t--> Found {len(cards)} of '{category}'.")

            success_count = 0

            for card in cards:
                    try:
                        div = card.find('div',class_='col-md-8')

                        # Article Title
                        headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')

                        # Article link
                        link = div.find('a')['href']
                        link = 'https://urdu.dunyanews.tv'+link
                        print(link)

                        # Requesting the content from each article's link
                        article_response = requests.get(link)
                        article_response.raise_for_status()
                        content_soup = BeautifulSoup(article_response.text, "html.parser")


                        # Content arranged in paras inside <span> tags
                        paras = content_soup.find('div',class_='main-news col-md-12').find_all('p')

                        combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                        )

                        # Storing data
                        dunya_df['id'].append(self.id)
                        dunya_df['title'].append(headline)
                        dunya_df['link'].append(link)
                        dunya_df['gold_label'].append(category.replace('Entertainment','entertainment').replace('Technology','science-technology').replace('Trade','business').replace('Sports','sports').replace('World','world'))
                        dunya_df['content'].append(combined_text)

                        # Increment ID and success count
                        self.id += 1
                        success_count += 1

                    except Exception as e:
                        print(f"\t--> Failed to scrape'{category}': {e}")
                    print(f"\t--> Successfully scraped {success_count} articles from'{category}'.")
            print('')

        return pd.DataFrame(dunya_df)

    def get_dawn_articles(self): #only one page
        dawn_df = {
            "id": [],
            "title": [],
            "link": [],
            "content": [],
            "gold_label": [],
        }
        base_url = 'https://www.dawnnews.tv'
        categories = ['life-style', 'business', 'sport', 'tech', 'world']


        # Iterating over the specified number of pages
        for category in categories:
            #for page in range(1, max_pages + 1):
            print(f"Scraping category '{category}'...")
            url = f"{base_url}/category/{category}"
            response = requests.get(url)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, "html.parser")

            # Finding article cards
            cards = soup.find_all('h2', class_='story__title')  # Adjust class as per actual site structure
            print(f"\t--> Found {len(cards)} of '{category}'.")

            success_count = 0

            for card in cards:
                try:
                    #div = card.find('div',class_='border-box')
                    div = card

                    # Article Title
                    headline = div.find('a').get_text(strip=True).replace('\xa0', ' ')
                    
                    # Article link
                    link = div.find('a', class_='story__link')['href']

                    # Requesting the content from each article's link
                    article_response = requests.get(link)
                    article_response.raise_for_status()
                    content_soup = BeautifulSoup(article_response.text, "html.parser")

                    # Content arranged in paras inside <span> tags
                    paras = content_soup.find('div',class_='story__content').find_all('p')

                    combined_text = " ".join(
                        p.get_text(strip=True).replace('\xa0', ' ').replace('\u200b', '')
                        for p in paras if p.get_text(strip=True)
                    )

                    # Storing data
                    dawn_df['id'].append(self.id)
                    dawn_df['title'].append(headline)
                    dawn_df['link'].append(link)
                    dawn_df['gold_label'].append(category.replace('life-style','entertainment').replace('technology','science-technology').replace('sport','sports').replace('tech','science-technology'))
                    dawn_df['content'].append(combined_text)

                    # Increment ID and success count
                    self.id += 1
                    success_count += 1

                except Exception as e:
                    print(f"\t--> Failed to scrape'{category}': {e}")

                print(f"\t--> Successfully scraped {success_count} articles from '{category}'.")
            print('')

        return pd.DataFrame(dawn_df)

# %%
scraper = NewsScraper()

# %%
df_express = scraper.get_express_articles(max_pages=7)
df_dunya = scraper.get_dunya_articles() 
df_jang = scraper.get_jang_articles()
df_geo = scraper.get_geo_urdu_articles()
df_dawn = scraper.get_dawn_articles()
# Out:
# Scraping page 1 of category 'saqafat'...
# 	--> Found 10 articles on page 1 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 1 of 'saqafat'.
# Scraping page 2 of category 'saqafat'...
# 	--> Found 10 articles on page 2 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 2 of 'saqafat'.
# Scraping page 3 of category 'saqafat'...
# 	--> Found 10 articles on page 3 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 3 of 'saqafat'.
# Scraping page 4 of category 'saqafat'...
# 	--> Found 10 articles on page 4 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 4 of 'saqafat'.
# Scraping page 5 of category 'saqafat'...
# 	--> Found 10 articles on page 5 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 5 of 'saqafat'.
# Scraping page 6 of category 'saqafat'...
# 	--> Found 10 articles on page 6 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 6 of 'saqafat'.
# Scraping page 7 of category 'saqafat'...
# 	--> Found 10 articles on page 7 of 'saqafat'.
# 	--> Successfully scraped 10 articles from page 7 of 'saqafat'.
#
# Scraping page 1 of category 'business'...
# 	--> Found 10 articles on page 1 of 'business'.
# 	--> Successfully scraped 10 articles from page 1 of 'business'.
# Scraping page 2 of category 'business'...
# 	--> Found 10 articles on page 2 of 'business'.
# 	--> Successfully scraped 10 articles from page 2 of 'business'.
# Scraping page 3 of category 'business'...
# 	--> Found 10 articles on page 3 of 'business'.
# 	--> Successfully scraped 10 articles from page 3 of 'business'.
# Scraping page 4 of category 'business'...
# 	--> Found 10 articles on page 4 of 'business'.
# 	--> Successfully scraped 10 articles from page 4 of 'business'.
# Scraping page 5 of category 'business'...
# 	--> Found 10 articles on page 5 of 'business'.
# 	--> Successfully scraped 10 articles from page 5 of 'business'.
# Scraping page 6 of category 'business'...
# 	--> Found 10 articles on page 6 of 'business'.
# 	--> Successfully scraped 10 articles from page 6 of 'business'.
# Scraping page 7 of category 'business'...
# 	--> Found 10 articles on page 7 of 'business'.
# 	--> Successfully scraped 10 articles from page 7 of 'business'.
#
# Scraping page 1 of category 'sports'...
# 	--> Found 10 articles on page 1 of 'sports'.
# 	--> Successfully scraped 10 articles from page 1 of 'sports'.
# Scraping page 2 of category 'sports'...
# 	--> Found 10 articles on page 2 of 'sports'.
# 	--> Successfully scraped 10 articles from page 2 of 'sports'.
# Scraping page 3 of category 'sports'...
# 	--> Found 10 articles on page 3 of 'sports'.
# 	--> Successfully scraped 10 articles from page 3 of 'sports'.
# Scraping page 4 of category 'sports'...
# 	--> Found 10 articles on page 4 of 'sports'.
# 	--> Successfully scraped 10 articles from page 4 of 'sports'.
# Scraping page 5 of category 'sports'...
# 	--> Successfully scraped 51 articles from 'business'.
# 	--> Successfully scraped 52 articles from 'business'.
# 	--> Successfully scraped 53 articles from 'business'.
# 	--> Successfully scraped 54 articles from 'business'.
# 	--> Successfully scraped 55 articles from 'business'.
# 	--> Successfully scraped 56 articles from 'business'.
# 	--> Successfully scraped 57 articles from 'business'.
# 	--> Successfully scraped 58 articles from 'business'.
# 	--> Successfully scraped 59 articles from 'business'.
# 	--> Successfully scraped 60 articles from 'business'.
# 	--> Successfully scraped 61 articles from 'business'.
# 	--> Successfully scraped 62 articles from 'business'.
# 	--> Successfully scraped 63 articles from 'business'.
# 	--> Successfully scraped 64 articles from 'business'.
# 	--> Successfully scraped 65 articles from 'business'.
# 	--> Successfully scraped 66 articles from 'business'.
# 	--> Successfully scraped 67 articles from 'business'.
# 	--> Successfully scraped 68 articles from 'business'.
# 	--> Successfully scraped 69 articles from 'business'.
# 	--> Successfully scraped 70 articles from 'business'.
# 	--> Successfully scraped 71 articles from 'business'.
#
# Scraping category 'sport'...
# 	--> Found 86 of 'sport'.
# 	--> Successfully scraped 1 articles from 'sport'.
# 	--> Successfully scraped 2 articles from 'sport'.
# 	--> Successfully scraped 3 articles from 'sport'.
# 	--> Successfully scraped 4 articles from 'sport'.
# 	--> Successfully scraped 5 articles from 'sport'.
# 	--> Successfully scraped 6 articles from 'sport'.
# 	--> Successfully scraped 7 articles from 'sport'.
# 	--> Successfully scraped 8 articles from 'sport'.
# 	--> Successfully scraped 9 articles from 'sport'.
# 	--> Successfully scraped 10 articles from 'sport'.
# 	--> Successfully scraped 11 articles from 'sport'.
# 	--> Successfully scraped 12 articles from 'sport'.
# 	--> Successfully scraped 13 articles from 'sport'.
# 	--> Successfully scraped 14 articles from 'sport'.
# 	--> Successfully scraped 15 articles from 'sport'.
# 	--> Successfully scraped 16 articles from 'sport'.
# 	--> Successfully scraped 17 articles from 'sport'.
# 	--> Successfully scraped 18 articles from 'sport'.
# 	--> Successfully scraped 19 articles from 'sport'.
# 	--> Successfully scraped 20 articles from 'sport'.
# 	--> Successfully scraped 21 articles from 'sport'.
# 	--> Successfully scraped 22 articles from 'sport'.
# 	--> Successfully scraped 23 articles from 'sport'.
# 	--> Successfully scraped 24 articles from 'sport'.
# 	--> Successfully scraped 25 articles from 'sport'.
# 	--> Successfully scraped 26 articles from 'sport'.
# 	--> Successfully scraped 27 articles from 'sport'.
# 	--> Successfully scraped 28 articles from 'sport'.
# 	--> Successfully scraped 29 articles from 'sport'.
# 	--> Successfully scraped 30 articles from 'sport'.
# 	--> Successfully scraped 31 articles from 'sport'.
# 	--> Successfully scraped 32 articles from 'sport'.
# 	--> Successfully scraped 33 articles from 'sport'.
# 	--> Successfully scraped 34 articles from 'sport'.
# 	--> Successfully scraped 35 articles from 'sport'.
# 	--> Successfully scraped 36 articles from 'sport'.
# 	--> Successfully scraped 37 articles from 'sport'.
# 	--> Successfully scraped 38 articles from 'sport'.
# 	--> Successfully scraped 39 articles from 'sport'.
# 	--> Successfully scraped 40 articles from 'sport'.
# 	--> Successfully scraped 41 articles from 'sport'.
# 	--> Successfully scraped 42 articles from 'sport'.
# 	--> Successfully scraped 43 articles from 'sport'.
# 	--> Successfully scraped 44 articles from 'sport'.
# 	--> Successfully scraped 45 articles from 'sport'.
# 	--> Successfully scraped 46 articles from 'sport'.
# 	--> Successfully scraped 47 articles from 'sport'.
# 	--> Successfully scraped 48 articles from 'sport'.
# 	--> Successfully scraped 49 articles from 'sport'.
# 	--> Successfully scraped 50 articles from 'sport'.
# 	--> Successfully scraped 51 articles from 'sport'.
# 	--> Successfully scraped 52 articles from 'sport'.
# 	--> Successfully scraped 53 articles from 'sport'.
# 	--> Successfully scraped 54 articles from 'sport'.
# 	--> Successfully scraped 55 articles from 'sport'.
# 	--> Successfully scraped 56 articles from 'sport'.
# 	--> Successfully scraped 57 articles from 'sport'.
# 	--> Successfully scraped 58 articles from 'sport'.
# 	--> Successfully scraped 59 articles from 'sport'.
# 	--> Successfully scraped 60 articles from 'sport'.
# 	--> Successfully scraped 61 articles from 'sport'.
# 	--> Successfully scraped 62 articles from 'sport'.
# 	--> Successfully scraped 63 articles from 'sport'.
# 	--> Successfully scraped 64 articles from 'sport'.
# 	--> Successfully scraped 65 articles from 'sport'.
# 	--> Successfully scraped 66 articles from 'sport'.
# 	--> Successfully scraped 67 articles from 'sport'.
# 	--> Successfully scraped 68 articles from 'sport'.
# 	--> Successfully scraped 69 articles from 'sport'.
# 	--> Successfully scraped 70 articles from 'sport'.
# 	--> Successfully scraped 71 articles from 'sport'.
# 	--> Successfully scraped 72 articles from 'sport'.
# 	--> Successfully scraped 73 articles from 'sport'.
# 	--> Successfully scraped 74 articles from 'sport'.
# 	--> Successfully scraped 75 articles from 'sport'.
# 	--> Successfully scraped 76 articles from 'sport'.
# 	--> Successfully scraped 77 articles from 'sport'.
# 	--> Successfully scraped 78 articles from 'sport'.
# 	--> Successfully scraped 79 articles from 'sport'.
# 	--> Successfully scraped 80 articles from 'sport'.
# 	--> Successfully scraped 81 articles from 'sport'.
# 	--> Successfully scraped 82 articles from 'sport'.
# 	--> Successfully scraped 83 articles from 'sport'.
# 	--> Successfully scraped 84 articles from 'sport'.
# 	--> Successfully scraped 85 articles from 'sport'.
# 	--> Successfully scraped 86 articles from 'sport'.
#
# Scraping category 'tech'...
# 	--> Found 82 of 'tech'.
# 	--> Successfully scraped 1 articles from 'tech'.
# 	--> Successfully scraped 2 articles from 'tech'.
# 	--> Successfully scraped 3 articles from 'tech'.
# 	--> Successfully scraped 4 articles from 'tech'.
# 	--> Successfully scraped 5 articles from 'tech'.
# 	--> Successfully scraped 6 articles from 'tech'.
# 	--> Successfully scraped 7 articles from 'tech'.
# 	--> Successfully scraped 8 articles from 'tech'.
# 	--> Successfully scraped 9 articles from 'tech'.
# 	--> Successfully scraped 10 articles from 'tech'.
# 	--> Successfully scraped 11 articles from 'tech'.
# 	--> Successfully scraped 12 articles from 'tech'.
# 	--> Successfully scraped 13 articles from 'tech'.
# 	--> Successfully scraped 14 articles from 'tech'.
# 	--> Successfully scraped 15 articles from 'tech'.
# 	--> Successfully scraped 16 articles from 'tech'.
# 	--> Successfully scraped 17 articles from 'tech'.
# 	--> Successfully scraped 18 articles from 'tech'.
# 	--> Successfully scraped 19 articles from 'tech'.
# 	--> Successfully scraped 20 articles from 'tech'.
# 	--> Successfully scraped 21 articles from 'tech'.
# 	--> Successfully scraped 22 articles from 'tech'.
# 	--> Successfully scraped 23 articles from 'tech'.
# 	--> Successfully scraped 24 articles from 'tech'.
# 	--> Successfully scraped 25 articles from 'tech'.
# 	--> Successfully scraped 26 articles from 'tech'.
# 	--> Successfully scraped 27 articles from 'tech'.
# 	--> Successfully scraped 28 articles from 'tech'.
# 	--> Successfully scraped 29 articles from 'tech'.
# 	--> Successfully scraped 30 articles from 'tech'.
# 	--> Successfully scraped 31 articles from 'tech'.
# 	--> Successfully scraped 32 articles from 'tech'.
# 	--> Successfully scraped 33 articles from 'tech'.
# 	--> Successfully scraped 34 articles from 'tech'.
# 	--> Successfully scraped 35 articles from 'tech'.
# 	--> Successfully scraped 36 articles from 'tech'.
# 	--> Successfully scraped 37 articles from 'tech'.
# 	--> Successfully scraped 38 articles from 'tech'.
# 	--> Successfully scraped 39 articles from 'tech'.
# 	--> Successfully scraped 40 articles from 'tech'.
# 	--> Successfully scraped 41 articles from 'tech'.
# 	--> Successfully scraped 42 articles from 'tech'.
# 	--> Successfully scraped 43 articles from 'tech'.
# 	--> Successfully scraped 44 articles from 'tech'.
# 	--> Successfully scraped 45 articles from 'tech'.
# 	--> Successfully scraped 46 articles from 'tech'.
# 	--> Successfully scraped 47 articles from 'tech'.
# 	--> Successfully scraped 48 articles from 'tech'.
# 	--> Successfully scraped 49 articles from 'tech'.
# 	--> Successfully scraped 50 articles from 'tech'.
# 	--> Successfully scraped 51 articles from 'tech'.
# 	--> Successfully scraped 52 articles from 'tech'.
# 	--> Successfully scraped 53 articles from 'tech'.
# 	--> Successfully scraped 54 articles from 'tech'.
# 	--> Successfully scraped 55 articles from 'tech'.
# 	--> Successfully scraped 56 articles from 'tech'.
# 	--> Successfully scraped 57 articles from 'tech'.
# 	--> Successfully scraped 58 articles from 'tech'.
# 	--> Successfully scraped 59 articles from 'tech'.
# 	--> Successfully scraped 60 articles from 'tech'.
# 	--> Successfully scraped 61 articles from 'tech'.
# 	--> Successfully scraped 62 articles from 'tech'.
# 	--> Successfully scraped 63 articles from 'tech'.
# 	--> Successfully scraped 64 articles from 'tech'.
# 	--> Successfully scraped 65 articles from 'tech'.
# 	--> Successfully scraped 66 articles from 'tech'.
# 	--> Successfully scraped 67 articles from 'tech'.
# 	--> Successfully scraped 68 articles from 'tech'.
# 	--> Successfully scraped 69 articles from 'tech'.
# 	--> Successfully scraped 70 articles from 'tech'.
# 	--> Successfully scraped 71 articles from 'tech'.
# 	--> Successfully scraped 72 articles from 'tech'.
# 	--> Successfully scraped 73 articles from 'tech'.
# 	--> Successfully scraped 74 articles from 'tech'.
# 	--> Successfully scraped 75 articles from 'tech'.
# 	--> Successfully scraped 76 articles from 'tech'.
# 	--> Successfully scraped 77 articles from 'tech'.
# 	--> Successfully scraped 78 articles from 'tech'.
# 	--> Successfully scraped 79 articles from 'tech'.
# 	--> Successfully scraped 80 articles from 'tech'.
# 	--> Successfully scraped 81 articles from 'tech'.
# 	--> Successfully scraped 82 articles from 'tech'.
#
# Scraping category 'world'...
# 	--> Found 106 of 'world'.
# 	--> Successfully scraped 1 articles from 'world'.
# 	--> Successfully scraped 2 articles from 'world'.
# 	--> Successfully scraped 3 articles from 'world'.
# 	--> Successfully scraped 4 articles from 'world'.
# 	--> Successfully scraped 5 articles from 'world'.
# 	--> Successfully scraped 6 articles from 'world'.
# 	--> Successfully scraped 7 articles from 'world'.
# 	--> Successfully scraped 8 articles from 'world'.
# 	--> Successfully scraped 9 articles from 'world'.
# 	--> Successfully scraped 10 articles from 'world'.
# 	--> Successfully scraped 11 articles from 'world'.
# 	--> Successfully scraped 12 articles from 'world'.
# 	--> Successfully scraped 13 articles from 'world'.
# 	--> Successfully scraped 14 articles from 'world'.
# 	--> Successfully scraped 15 articles from 'world'.
# 	--> Successfully scraped 16 articles from 'world'.
# 	--> Successfully scraped 17 articles from 'world'.
# 	--> Successfully scraped 18 articles from 'world'.
# 	--> Successfully scraped 19 articles from 'world'.
# 	--> Successfully scraped 20 articles from 'world'.
# 	--> Successfully scraped 21 articles from 'world'.
# 	--> Successfully scraped 22 articles from 'world'.
# 	--> Successfully scraped 23 articles from 'world'.
# 	--> Successfully scraped 24 articles from 'world'.
# 	--> Successfully scraped 25 articles from 'world'.
# 	--> Successfully scraped 26 articles from 'world'.
# 	--> Successfully scraped 27 articles from 'world'.
# 	--> Successfully scraped 28 articles from 'world'.
# 	--> Successfully scraped 29 articles from 'world'.
# 	--> Successfully scraped 30 articles from 'world'.
# 	--> Successfully scraped 31 articles from 'world'.
# 	--> Successfully scraped 32 articles from 'world'.
# 	--> Successfully scraped 33 articles from 'world'.
# 	--> Successfully scraped 34 articles from 'world'.
# 	--> Successfully scraped 35 articles from 'world'.
# 	--> Successfully scraped 36 articles from 'world'.
# 	--> Successfully scraped 37 articles from 'world'.
# 	--> Successfully scraped 38 articles from 'world'.
# 	--> Successfully scraped 39 articles from 'world'.
# 	--> Successfully scraped 40 articles from 'world'.
# 	--> Successfully scraped 41 articles from 'world'.
# 	--> Successfully scraped 42 articles from 'world'.
# 	--> Successfully scraped 43 articles from 'world'.
# 	--> Successfully scraped 44 articles from 'world'.
# 	--> Successfully scraped 45 articles from 'world'.
# 	--> Successfully scraped 46 articles from 'world'.
# 	--> Successfully scraped 47 articles from 'world'.
# 	--> Successfully scraped 48 articles from 'world'.
# 	--> Successfully scraped 49 articles from 'world'.
# 	--> Successfully scraped 50 articles from 'world'.
# 	--> Successfully scraped 51 articles from 'world'.
# 	--> Successfully scraped 52 articles from 'world'.
# 	--> Successfully scraped 53 articles from 'world'.
# 	--> Successfully scraped 54 articles from 'world'.
# 	--> Successfully scraped 55 articles from 'world'.
# 	--> Successfully scraped 56 articles from 'world'.
# 	--> Successfully scraped 57 articles from 'world'.
# 	--> Successfully scraped 58 articles from 'world'.
# 	--> Successfully scraped 59 articles from 'world'.
# 	--> Successfully scraped 60 articles from 'world'.
# 	--> Successfully scraped 61 articles from 'world'.
# 	--> Successfully scraped 62 articles from 'world'.
# 	--> Successfully scraped 63 articles from 'world'.
# 	--> Successfully scraped 64 articles from 'world'.
# 	--> Successfully scraped 65 articles from 'world'.
# 	--> Successfully scraped 66 articles from 'world'.
# 	--> Successfully scraped 67 articles from 'world'.
# 	--> Successfully scraped 68 articles from 'world'.
# 	--> Successfully scraped 69 articles from 'world'.
# 	--> Successfully scraped 70 articles from 'world'.
# 	--> Successfully scraped 71 articles from 'world'.
# 	--> Successfully scraped 72 articles from 'world'.
# 	--> Successfully scraped 73 articles from 'world'.
# 	--> Successfully scraped 74 articles from 'world'.
# 	--> Successfully scraped 75 articles from 'world'.
# 	--> Successfully scraped 76 articles from 'world'.
# 	--> Successfully scraped 77 articles from 'world'.
# 	--> Successfully scraped 78 articles from 'world'.
# 	--> Successfully scraped 79 articles from 'world'.
# 	--> Successfully scraped 80 articles from 'world'.
# 	--> Successfully scraped 81 articles from 'world'.
# 	--> Successfully scraped 82 articles from 'world'.
# 	--> Successfully scraped 83 articles from 'world'.
# 	--> Successfully scraped 84 articles from 'world'.
# 	--> Successfully scraped 85 articles from 'world'.
# 	--> Successfully scraped 86 articles from 'world'.
# 	--> Successfully scraped 87 articles from 'world'.
# 	--> Successfully scraped 88 articles from 'world'.
# 	--> Successfully scraped 89 articles from 'world'.
# 	--> Successfully scraped 90 articles from 'world'.
# 	--> Successfully scraped 91 articles from 'world'.
# 	--> Successfully scraped 92 articles from 'world'.
# 	--> Successfully scraped 93 articles from 'world'.
# 	--> Successfully scraped 94 articles from 'world'.
# 	--> Successfully scraped 95 articles from 'world'.
# 	--> Successfully scraped 96 articles from 'world'.
# 	--> Successfully scraped 97 articles from 'world'.
# 	--> Successfully scraped 98 articles from 'world'.
# 	--> Successfully scraped 99 articles from 'world'.
# 	--> Successfully scraped 100 articles from 'world'.
# 	--> Successfully scraped 101 articles from 'world'.
# 	--> Successfully scraped 102 articles from 'world'.
# 	--> Successfully scraped 103 articles from 'world'.
# 	--> Successfully scraped 104 articles from 'world'.
# 	--> Successfully scraped 105 articles from 'world'.
# 	--> Successfully scraped 106 articles from 'world'.

# %% [markdown]
# # Output
# - Save a combined csv of all 3 sites.

# %%
df = pd.concat([df_express, df_dunya, df_jang, df_geo, df_dawn], ignore_index=True)
df.to_csv("raw_data.csv", index=False)

# %%
print(df_express.shape)
print(df_dunya.shape)
print(df_dawn.shape)
print(df_jang.shape)
print(df_geo.shape)
# Out:
# (350, 5)
# (180, 5)
# (409, 5)
# (494, 5)
# (300, 5)
